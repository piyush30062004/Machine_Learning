# %% [markdown]
# <a href="https://colab.research.google.com/github/piyush30062004/Machine_Learning/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Worls")
# Out:
# Hello Worls
